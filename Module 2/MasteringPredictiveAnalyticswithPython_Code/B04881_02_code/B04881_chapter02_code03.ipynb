# %%
# %matplotlib inline

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import geopandas as geo

# %%
africa_map = geo.GeoDataFrame.from_file('Africa_SHP/Africa.shp')

# %%
africa_map.columns
# Out:
# Index(['CODE', 'COUNTRY', 'ID', 'geometry'], dtype='object')

# %%
africa_map.head()
# Out:
#   CODE  COUNTRY ID                                           geometry
# 0  ALG  Algeria  1  POLYGON ((-5.7636199999979 25.58624999999302, ...
# 1  ANG   Angola  2  POLYGON ((13.36632442474365 -8.32172966003418,...
# 2  ANG   Angola  3  POLYGON ((12.80576000000292 -4.806490000002668...
# 3  ANG   Angola  4  POLYGON ((11.76834011077881 -16.79932975769043...
# 4  ANG   Angola  5  POLYGON ((12.89840030670166 -5.988018989562988...

# %%
africa_map.plot(column='CODE')

# %%
africa_populations = pd.read_csv('Africa_populations.tsv',sep='\t')

# %%
africa_map = pd.merge(africa_map,africa_populations,left_on='COUNTRY',right_on='Country_Name')

# %%
africa_map.plot(column='Population',colormap='hot')
